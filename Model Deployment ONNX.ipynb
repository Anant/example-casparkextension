# %%
pip install onnx
# Out:
# Requirement already satisfied: onnx in /opt/conda/lib/python3.7/site-packages (1.7.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /opt/conda/lib/python3.7/site-packages (from onnx) (3.7.4.2)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.7/site-packages (from onnx) (3.11.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from onnx) (1.18.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from onnx) (1.14.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf->onnx) (46.1.3.post20200325)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import cassandra
import pyspark
import re
import os
import random
from random import randint, randrange
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StringIndexer
from pyspark.ml.clustering import KMeans
import seaborn as sns
from pyspark.ml.stat import Correlation
from pyspark.mllib.linalg.distributed import RowMatrix
from pyspark.ml.feature import PCA, Imputer
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.sql.functions import col, asc
from pyspark.sql.functions import isnan
from pyspark.sql.functions import udf
from pyspark.sql import functions as F
import numpy as np
import itertools
from sklearn.metrics import confusion_matrix
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.linalg import Vectors
from pyspark.ml.tuning import CrossValidatorModel
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

from onnxmltools import convert_sparkml
from onnxmltools.convert.sparkml.utils import buildInitialTypesSimple, buildInputDictSimple
from pyspark.ml import Pipeline
import onnx
import onnxruntime

# %%
#Helper for pretty formatting for Spark DataFrames
def showDF(df, limitRows =  5, truncate = True):
    if(truncate):
        pd.set_option('display.max_colwidth', 50)
    else:
        pd.set_option('display.max_colwidth', -1)
    pd.set_option('display.max_rows', limitRows)
    display(df.limit(limitRows).toPandas())
    pd.reset_option('display.max_rows')

# %%
def correlation_matrix(df, corr_columns, method='pearson'):
    vector_col = "corr_features"
    assembler = VectorAssembler(inputCols=corr_columns, outputCol=vector_col)
    df_vector = assembler.transform(df).select(vector_col)
    matrix = Correlation.corr(df_vector, vector_col, method)

    result = matrix.collect()[0]["pearson({})".format(vector_col)].values
    return pd.DataFrame(result.reshape(-1, len(corr_columns)), columns=corr_columns, index=corr_columns)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Model 1')
    plt.xlabel('Model 2')

# %%
from cassandra.cluster import Cluster

cluster = Cluster(['dse'])
session = cluster.connect()

# %%
session.execute("""
    CREATE KEYSPACE IF NOT EXISTS accelerate 
    WITH REPLICATION = 
    { 'class' : 'SimpleStrategy', 'replication_factor' : 1 }"""
)

# %%
session.set_keyspace('accelerate')

# %%
query = "CREATE TABLE IF NOT EXISTS diabetes \
                                   (Id int, timesPregnant int, plasmaGlucose int, bloodPressure int, \
                                   tricepThickness int, serumInsulin int, bmi float, diabetesPedegree float, \
                                   age int, label int, PRIMARY KEY (Id))"
session.execute(query)

# %%
fileName = 'data/pima-indians-diabetes.csv'
input_file = open(fileName, 'r')
i = 1
for line in input_file:
    iD = i
    row = line.split(',')

    query = "INSERT INTO diabetes (Id, timesPregnant, plasmaGlucose, bloodPressure, \
                                   tricepThickness, serumInsulin, bmi, diabetesPedegree, \
                                   age, label)"
    query = query + " VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    session.execute(query, (int(iD), int(row[0]), int(row[1]), int(row[2]), int(row[3]), int(row[4]), float(row[5]), float(row[6]), int(row[7]), int(row[8])))
    i = i + 1

# %%
spark = SparkSession.builder.appName('demo').master("local").getOrCreate()
diabetesDF = spark.read.format("org.apache.spark.sql.cassandra").options(table="diabetes", keyspace="accelerate").load()

print ("Table Row Count: ")
print (diabetesDF.count())
# Out:
# Table Row Count:
# 768

# %%
print(diabetesDF.schema.names)
print([diabetesDF.where((col(c_name) == 0)).count() for c_name in diabetesDF.schema.names])
# Out:
# ['id', 'age', 'bloodpressure', 'bmi', 'diabetespedegree', 'label', 'plasmaglucose', 'seruminsulin', 'timespregnant', 'tricepthickness']
# [0, 0, 35, 11, 0, 500, 5, 374, 111, 227]

# %%
diabetesDF = diabetesDF.withColumn("bloodpressure", F.when(F.col("bloodpressure")==0, float("nan")).otherwise(F.col("bloodpressure")))
diabetesDF = diabetesDF.withColumn("plasmaglucose", F.when(F.col("plasmaglucose")==0, float("nan")).otherwise(F.col("plasmaglucose")))
diabetesDF = diabetesDF.withColumn("tricepthickness", F.when(F.col("tricepthickness")==0, float("nan")).otherwise(F.col("tricepthickness")))
diabetesDF = diabetesDF.withColumn("seruminsulin", F.when(F.col("seruminsulin")==0, float("nan")).otherwise(F.col("seruminsulin")))
diabetesDF = diabetesDF.withColumn("bmi", F.when(F.col("bmi")==0, float("nan")).otherwise(F.col("bmi")))

# %%
print(diabetesDF.schema.names)
print([diabetesDF.where((col(c_name) == 0)).count() for c_name in diabetesDF.schema.names])
# Out:
# ['id', 'age', 'bloodpressure', 'bmi', 'diabetespedegree', 'label', 'plasmaglucose', 'seruminsulin', 'timespregnant', 'tricepthickness']
# [0, 0, 0, 0, 0, 500, 0, 0, 111, 0]

# %%
imputer = Imputer()
imputer.setInputCols(["plasmaglucose", "bloodpressure", "bmi", "tricepthickness", "seruminsulin"])
imputer.setOutputCols(["out_plasmaglucose", "out_bloodpressure", "out_bmi", "out_tricepthickness", "out_seruminsulin"])
model = imputer.fit(diabetesDF)
#model.setInputCols(["plasmaglucose", "bloodpressure", "bmi"])
diabetesDF_imputed = model.transform(diabetesDF)
showDF(diabetesDF_imputed,100)
# Out:
#      id  age  bloodpressure        bmi  diabetespedegree  label  \
# 0    23   41           90.0  39.799999             0.451      1
# 1   114   25           62.0  34.000000             0.391      0
# 2   660   27           82.0  34.200001             1.292      1
# 3    53   30           66.0  24.400000             0.342      0
# 4   110   24           85.0  37.400002             0.247      1
# 5    91   21           55.0  19.100000             0.258      0
# 6   128   23           58.0  33.299999             0.261      0
# 7   363   65          108.0  39.200001             0.305      0
# 8   251   42           52.0  31.200001             0.380      0
# 9   744   45           94.0  32.700001             0.734      1
# 10  310   30           68.0  32.900002             0.875      1
# 11  247   41           68.0  31.200001             0.258      0
# 12  214   24           65.0  42.599998             0.431      1
# 13  429   26           94.0  40.599998             0.284      0
# 14  117   38           74.0  34.000000             0.220      1
# 15  547   53           76.0  43.599998             1.034      1
# 16  144   42           66.0  32.400002             0.272      1
# 17  718   56           72.0  23.100000             0.595      0
# 18  567   21           72.0  38.599998             0.412      0
# 19  120   21           76.0  23.200001             0.223      0
# 20  504   41           64.0  33.299999             0.738      0
# 21  729   22           88.0  22.900000             0.326      0
# 22  219   32           74.0  29.000000             1.224      1
# 23  695   25           60.0  23.500000             0.191      0
# 24  475   24           64.0  28.900000             0.126      0
# 25  140   28           72.0  36.900002             0.159      0
# 26  308   21           68.0  24.799999             0.143      0
# 27  483   28           58.0  27.799999             0.306      0
# 28   55   42           66.0  34.700001             0.718      0
# 29  441   41          104.0  34.299999             0.435      1
# 30  662   22           76.0  42.900002             1.394      1
# 65          129.0         115.0              3             29.0  26.400000
# 66          106.0           NaN              7             24.0  26.500000
# 67           85.0           NaN              2              NaN  39.599998
# 68          155.0          96.0              2             17.0  26.600000
# 69          107.0         100.0              2             30.0  33.599998
# 70          105.0         191.0              2             45.0  33.700001
# 71          133.0           NaN              7              NaN  40.200001
# 72          194.0           NaN              6              NaN  23.500000
# 73          156.0         155.0              9             28.0  34.299999
# 74          129.0         130.0              0             46.0  67.099998
# 75          124.0           NaN              0             20.0  27.400000
# 76           57.0           NaN              0              NaN  21.700001
# 77          165.0         680.0              0             33.0  52.299999
# 78          105.0           NaN              7              NaN  32.457464
# 79          174.0         120.0              2             37.0  44.500000
# 80          131.0         166.0              4             21.0  33.099998
# 81           91.0           NaN              2              NaN  27.299999
# 82          142.0          64.0              2             18.0  24.700001
# 83          145.0           NaN              0              NaN  44.200001
# 84           92.0          41.0              1             25.0  19.500000
# 85          123.0           NaN              0              NaN  36.299999
# 86          100.0          71.0              2             25.0  38.500000
# 87          103.0         152.0              3             30.0  27.600000
# 88           74.0           NaN              2              NaN  32.457464
# 89           98.0          84.0              0             15.0  25.200001
# 90          103.0           NaN              7             32.0  39.099998
# 91          125.0           NaN              8              NaN  32.457464
# 92          101.0          90.0              2             35.0  21.799999
# 93          115.0           NaN             10              NaN  24.000000
# 94           74.0          36.0              0             10.0  27.799999
# 95          100.0          56.0              1             15.0  23.600000
# 96          145.0         130.0              9             46.0  37.900002
# 97          100.0          50.0              0             26.0  30.799999
# 98          174.0         194.0              3             22.0  32.900002
# 99          105.0           NaN              0             22.0  20.000000
#
#     out_plasmaglucose  out_tricepthickness  out_seruminsulin  \
# 0               196.0             29.15342        155.548223
# 1                76.0             29.15342        155.548223
# 2                80.0             31.00000         70.000000
# 3                88.0             21.00000         23.000000
# 4                95.0             25.00000         36.000000
# 5                80.0             29.15342        155.548223
# 6               118.0             36.00000         94.000000
# 7               103.0             37.00000        155.548223
# 8               106.0             29.15342        155.548223
# 9               140.0             29.15342        155.548223
# 10              124.0             28.00000        205.000000
# 11              122.0             29.15342        155.548223
# 12              140.0             26.00000        130.000000
# 13              135.0             46.00000        145.000000
# 14              124.0             29.15342        155.548223
# 15              187.0             27.00000        207.000000
# 16              108.0             29.15342        155.548223
# 17               94.0             18.00000        155.548223
# 18               99.0             30.00000         18.000000
# 19               99.0             15.00000         51.000000
# 20               94.0             25.00000         79.000000
# 21              175.0             29.15342        155.548223
# 22               85.0             22.00000        155.548223
# 23               90.0             29.15342        155.548223
# 24              114.0             29.15342        155.548223
# 25              105.0             29.00000        325.000000
# 26              137.0             14.00000        148.000000
# 27               85.0             22.00000         49.000000
# 28              150.0             42.00000        342.000000
# 29              189.0             25.00000        155.548223
# 30              199.0             43.00000        155.548223
# 31               92.0              7.00000        258.000000
# 32              118.0             19.00000        155.548223
# 33              117.0             24.00000        145.000000
# 34              111.0             29.15342        155.548223
# 35              114.0             29.15342        155.548223
# 36              116.0             28.00000        155.548223
# 37              136.0             35.00000        130.000000
# 38              122.0             27.00000        200.000000
# 39              157.0             35.00000        440.000000
# 40              137.0             27.00000        155.548223
# 41               91.0             29.15342        155.548223
# 42              147.0             29.15342        155.548223
# 43              152.0             33.00000         29.000000
# 44               97.0             15.00000        155.548223
# 45               84.0             22.00000         66.000000
# 46               87.0             16.00000         52.000000
# 47              183.0             29.15342        155.548223
# 48               88.0             11.00000         54.000000
# 49              122.0             29.15342        155.548223
# 50               77.0             30.00000         56.000000
# 51               93.0             39.00000         72.000000
# 52              183.0             29.15342        155.548223
# 53              108.0             46.00000        178.000000
# 54              178.0             29.15342        155.548223
# 55               80.0             36.00000        155.548223
# 56              117.0             19.00000         71.000000
# 57              102.0             46.00000         78.000000
# 58               71.0             50.00000         45.000000
# 59              141.0             29.15342        155.548223
# 60              137.0             35.00000        168.000000
# 61              136.0             29.15342        155.548223
# 62               97.0             15.00000        140.000000
# 63              112.0             24.00000        155.548223
# 64               81.0             16.00000         66.000000
# 65              129.0             29.00000        115.000000
# 66              106.0             24.00000        155.548223
# 67               85.0             29.15342        155.548223
# 68              155.0             17.00000         96.000000
# 69              107.0             30.00000        100.000000
# 70              105.0             45.00000        191.000000
# 71              133.0             29.15342        155.548223
# 72              194.0             29.15342        155.548223
# 73              156.0             28.00000        155.000000
# 74              129.0             46.00000        130.000000
# 75              124.0             20.00000        155.548223
# 76               57.0             29.15342        155.548223
# 77              165.0             33.00000        680.000000
# 78              105.0             29.15342        155.548223
# 79              174.0             37.00000        120.000000
# 80              131.0             21.00000        166.000000
# 81               91.0             29.15342        155.548223
# 82              142.0             18.00000         64.000000
# 83              145.0             29.15342        155.548223
# 84               92.0             25.00000         41.000000
# 85              123.0             29.15342        155.548223
# 86              100.0             25.00000         71.000000
# 87              103.0             30.00000        152.000000
# 88               74.0             29.15342        155.548223
# 89               98.0             15.00000         84.000000
# 90              103.0             32.00000        155.548223
# 91              125.0             29.15342        155.548223
# 92              101.0             35.00000         90.000000
# 93              115.0             29.15342        155.548223
# 94               74.0             10.00000         36.000000
# 95              100.0             15.00000         56.000000
# 96              145.0             46.00000        130.000000
# 97              100.0             26.00000         50.000000
# 98              174.0             22.00000        194.000000
# 99              105.0             22.00000        155.548223
#
#     out_bloodpressure
# 0           90.000000
# 1           62.000000
# 2           82.000000
# 3           66.000000
# 4           85.000000
# 5           55.000000
# 6           58.000000
# 7          108.000000
# 8           52.000000
# 9           94.000000
# 10          68.000000
# 11          68.000000
# 12          65.000000
# 13          94.000000
# 14          74.000000
# 15          76.000000
# 16          66.000000
# 17          72.000000
# 18          72.000000
# 19          76.000000
# 20          64.000000
# 21          88.000000
# 22          74.000000
# 23          60.000000
# 24          64.000000
# 25          72.000000
# 26          68.000000
# 27          58.000000
# 28          66.000000
# 29         104.000000
# 30          76.000000
# 31          62.000000
# 32          72.000000
# 33          88.000000
# 34          65.000000
# 35          64.000000
# 36          70.000000
# 37          84.000000
# 38          76.000000
# 39          74.000000
# 40          84.000000
# 41          72.405184
# 42          75.000000
# 43          90.000000
# 44          70.000000
# 45          64.000000
# 46          58.000000
# 47          94.000000
# 48          58.000000
# 49          56.000000
# 50          56.000000
# 51         100.000000
# 52          72.405184
# 53          60.000000
# 54          84.000000
# 55          80.000000
# 56          90.000000
# 57          64.000000
# 58          78.000000
# 59          74.000000
# 60          40.000000
# 61          70.000000
# 62          66.000000
# 63          82.000000
# 64          86.000000
# 65          64.000000
# 66          60.000000
# 67          65.000000
# 68          74.000000
# 69          74.000000
# 70          80.000000
# 71          84.000000
# 72          78.000000
# 73          86.000000
# 74         110.000000
# 75          70.000000
# 76          60.000000
# 77          90.000000
# 78          72.405184
# 79          88.000000
# 80          68.000000
# 81          62.000000
# 82          82.000000
# 83          72.405184
# 84          62.000000
# 85          72.000000
# 86          68.000000
# 87          72.000000
# 88          72.405184
# 89          82.000000
# 90          66.000000
# 91          96.000000
# 92          58.000000
# 93          98.000000
# 94          52.000000
# 95          66.000000
# 96          80.000000
# 97          70.000000
# 98          58.000000
# 99          68.000000

# %%
initial_types = buildInitialTypesSimple(diabetesDF.drop("label").drop("id").drop("age").drop("diabetespedegree").drop("timespregnant"))
print(initial_types)
onnx_model = convert_sparkml(model, 'Pyspark Imputer model', initial_types, spark_session = spark)
#print(onnx_model.SerializeToString())
# Out:
# The maximum opset needed by this model is only 4.
# [('bloodpressure', FloatTensorType(shape=[1, 1])), ('bmi', FloatTensorType(shape=[1, 1])), ('plasmaglucose', FloatTensorType(shape=[1, 1])), ('seruminsulin', FloatTensorType(shape=[1, 1])), ('tricepthickness', FloatTensorType(shape=[1, 1]))]
# b'\x08\x03\x12\x0bOnnxMLTools\x1a\x051.7.0"\x14onnxconverter-common(\x002\x00:\x83\x06\np\n\rplasmaglucose\n\rbloodpressure\n\x03bmi\n\x0ftricepthickness\n\x0cseruminsulin\x12\rconcat_tensor\x1a\x06Concat"\x06Concat*\x0b\n\x04axis\x18\x01\xa0\x01\x02:\x00\n\x91\x01\n\rconcat_tensor\x12\x0eimputed_tensor\x1a\x07Imputer"\x07Imputer*2\n\x14imputed_value_floats=\x9f_\xf3B=t\xcf\x90B=q\xd4\x01B=4:\xe9A=X\x8c\x1bC\xa0\x01\x06*\x1e\n\x14replaced_value_float\x15\x00\x00\xc0\x7f\xa0\x01\x01:\nai.onnx.ml\n\x97\x01\n\x0eimputed_tensor\x12\x11out_plasmaglucose\x12\x11out_bloodpressure\x12\x07out_bmi\x12\x13out_tricepthickness\x12\x10out_seruminsulin\x1a\x05Split"\x05Split*\x0b\n\x04axis\x18\x01\xa0\x01\x02*\x12\n\x05split@\x01@\x02@\x03@\x04\xa0\x01\x07:\x00\x12\x15Pyspark Imputer modelZ\x1f\n\rbloodpressure\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01Z\x15\n\x03bmi\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01Z\x1f\n\rplasmaglucose\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01Z\x1e\n\x0cseruminsulin\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01Z!\n\x0ftricepthickness\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01b#\n\x11out_plasmaglucose\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01b#\n\x11out_bloodpressure\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01b\x19\n\x07out_bmi\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01b%\n\x13out_tricepthickness\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01b"\n\x10out_seruminsulin\x12\x0e\n\x0c\x08\x01\x12\x08\n\x02\x08\x01\n\x02\x08\x01B\x0e\n\nai.onnx.ml\x10\x01B\x04\n\x00\x10\x04'

# %%
with open(os.path.join("/home/jovyan/work/models/", "imputer_model.onnx"), "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# 93          115.0           NaN             10              NaN  24.000000
# 94           74.0          36.0              0             10.0  27.799999
# 95          100.0          56.0              1             15.0  23.600000
# 96          145.0         130.0              9             46.0  37.900002
# 97          100.0          50.0              0             26.0  30.799999
# 98          174.0         194.0              3             22.0  32.900002
# 99          105.0           NaN              0             22.0  20.000000
#
#     out_plasmaglucose  out_tricepthickness  out_seruminsulin  \
# 0               196.0             29.15342        155.548223
# 1                76.0             29.15342        155.548223
# 2                80.0             31.00000         70.000000
# 3                88.0             21.00000         23.000000
# 4                95.0             25.00000         36.000000
# 5                80.0             29.15342        155.548223
# 6               118.0             36.00000         94.000000
# 7               103.0             37.00000        155.548223
# 8               106.0             29.15342        155.548223
# 9               140.0             29.15342        155.548223
# 10              124.0             28.00000        205.000000
# 11              122.0             29.15342        155.548223
# 12              140.0             26.00000        130.000000
# 13              135.0             46.00000        145.000000
# 14              124.0             29.15342        155.548223
# 15              187.0             27.00000        207.000000
# 16              108.0             29.15342        155.548223
# 17               94.0             18.00000        155.548223
# 18               99.0             30.00000         18.000000
# 19               99.0             15.00000         51.000000
# 20               94.0             25.00000         79.000000
# 21              175.0             29.15342        155.548223
# 22               85.0             22.00000        155.548223
# 23               90.0             29.15342        155.548223
# 24              114.0             29.15342        155.548223
# 25              105.0             29.00000        325.000000
# 26              137.0             14.00000        148.000000
# 27               85.0             22.00000         49.000000
# 28              150.0             42.00000        342.000000
# 29              189.0             25.00000        155.548223
# 30              199.0             43.00000        155.548223
# 31               92.0              7.00000        258.000000
# 32              118.0             19.00000        155.548223
# 33              117.0             24.00000        145.000000
# 34              111.0             29.15342        155.548223
# 35              114.0             29.15342        155.548223
# 36              116.0             28.00000        155.548223
# 37              136.0             35.00000        130.000000
# 38              122.0             27.00000        200.000000
# 39              157.0             35.00000        440.000000
# 40              137.0             27.00000        155.548223
# 41               91.0             29.15342        155.548223
# 42              147.0             29.15342        155.548223
# 43              152.0             33.00000         29.000000
# 44               97.0             15.00000        155.548223
# 45               84.0             22.00000         66.000000
# 46               87.0             16.00000         52.000000
# 47              183.0             29.15342        155.548223
# 48               88.0             11.00000         54.000000
# 49              122.0             29.15342        155.548223
# 50               77.0             30.00000         56.000000
# 51               93.0             39.00000         72.000000
# 52              183.0             29.15342        155.548223
# 53              108.0             46.00000        178.000000
# 54              178.0             29.15342        155.548223
# 55               80.0             36.00000        155.548223
# 56              117.0             19.00000         71.000000
# 57              102.0             46.00000         78.000000
# 58               71.0             50.00000         45.000000
# 59              141.0             29.15342        155.548223
# 60              137.0             35.00000        168.000000
# 61              136.0             29.15342        155.548223
# 62               97.0             15.00000        140.000000
# 63              112.0             24.00000        155.548223
# 64               81.0             16.00000         66.000000
# 65              129.0             29.00000        115.000000
# 66              106.0             24.00000        155.548223
# 67               85.0             29.15342        155.548223
# 68              155.0             17.00000         96.000000
# 69              107.0             30.00000        100.000000
# 70              105.0             45.00000        191.000000
# 71              133.0             29.15342        155.548223
# 72              194.0             29.15342        155.548223
# 73              156.0             28.00000        155.000000
# 74              129.0             46.00000        130.000000
# 75              124.0             20.00000        155.548223
# 76               57.0             29.15342        155.548223
# 77              165.0             33.00000        680.000000
# 78              105.0             29.15342        155.548223
# 79              174.0             37.00000        120.000000
# 80              131.0             21.00000        166.000000
# 81               91.0             29.15342        155.548223
# 82              142.0             18.00000         64.000000
# 83              145.0             29.15342        155.548223
# 84               92.0             25.00000         41.000000
# 85              123.0             29.15342        155.548223
# 86              100.0             25.00000         71.000000
# 87              103.0             30.00000        152.000000
# 88               74.0             29.15342        155.548223
# 89               98.0             15.00000         84.000000
# 90              103.0             32.00000        155.548223
# 91              125.0             29.15342        155.548223
# 92              101.0             35.00000         90.000000
# 93              115.0             29.15342        155.548223
# 94               74.0             10.00000         36.000000
# 95              100.0             15.00000         56.000000
# 96              145.0             46.00000        130.000000
# 97              100.0             26.00000         50.000000
# 98              174.0             22.00000        194.000000
# 99              105.0             22.00000        155.548223
#
#     out_bloodpressure
# 0           90.000000
# 1           62.000000
# 2           82.000000
# 3           66.000000
# 4           85.000000
# 5           55.000000
# 6           58.000000
# 7          108.000000
# 8           52.000000
# 9           94.000000
# 10          68.000000
# 11          68.000000
# 12          65.000000
# 13          94.000000
# 14          74.000000
# 15          76.000000
# 16          66.000000
# 17          72.000000
# 18          72.000000
# 19          76.000000
# 20          64.000000
# 21          88.000000
# 22          74.000000
# 23          60.000000
# 24          64.000000
# 25          72.000000
# 26          68.000000
# 27          58.000000
# 28          66.000000
# 29         104.000000
# 30          76.000000
# 31          62.000000
# 32          72.000000
# 33          88.000000
# 34          65.000000
# 35          64.000000
# 36          70.000000
# 37          84.000000
# 38          76.000000
# 39          74.000000
# 40          84.000000
# 41          72.405184
# 42          75.000000
# 43          90.000000
# 44          70.000000
# 45          64.000000
# 46          58.000000
# 47          94.000000
# 48          58.000000
# 49          56.000000
# 50          56.000000
# 51         100.000000
# 52          72.405184
# 53          60.000000
# 54          84.000000
# 55          80.000000
# 56          90.000000
# 57          64.000000
# 58          78.000000
# 59          74.000000
# 60          40.000000
# 61          70.000000
# 62          66.000000
# 63          82.000000
# 64          86.000000
# 65          64.000000
# 66          60.000000
# 67          65.000000
# 68          74.000000
# 69          74.000000
# 70          80.000000
# 71          84.000000
# 72          78.000000
# 73          86.000000
# 74         110.000000
# 75          70.000000
# 76          60.000000
# 77          90.000000
# 78          72.405184
# 79          88.000000
# 80          68.000000
# 81          62.000000
# 82          82.000000
# 83          72.405184
# 84          62.000000
# 85          72.000000
# 86          68.000000
# 87          72.000000
# 88          72.405184
# 89          82.000000
# 90          66.000000
# 91          96.000000
# 92          58.000000
# 93          98.000000
# 94          52.000000
# 95          66.000000
# 96          80.000000
# 97          70.000000
# 98          58.000000
# 99          68.000000

# %%
assembler = VectorAssembler(
    inputCols=['age', 'out_bloodpressure', 'out_bmi', 'diabetespedegree', 'out_plasmaglucose', 'out_seruminsulin', 'timespregnant', 'out_tricepthickness'],
    outputCol='features', handleInvalid = "keep")

dDF = assembler.transform(diabetesDF_imputed)
showDF(dDF)
# Out:
#     id  age  bloodpressure        bmi  diabetespedegree  label  plasmaglucose  \
# 0   23   41           90.0  39.799999             0.451      1          196.0
# 1  114   25           62.0  34.000000             0.391      0           76.0
# 2  660   27           82.0  34.200001             1.292      1           80.0
# 3   53   30           66.0  24.400000             0.342      0           88.0
# 4  110   24           85.0  37.400002             0.247      1           95.0
#
#    seruminsulin  timespregnant  tricepthickness    out_bmi  out_plasmaglucose  \
# 0           NaN              7              NaN  39.799999              196.0
# 1           NaN              4              NaN  34.000000               76.0
# 2          70.0              3             31.0  34.200001               80.0
# 3          23.0              5             21.0  24.400000               88.0
# 4          36.0              0             25.0  37.400002               95.0
#
#    out_tricepthickness  out_seruminsulin  out_bloodpressure  \
# 0             29.15342        155.548223               90.0
# 1             29.15342        155.548223               62.0
# 2             31.00000         70.000000               82.0
# 3             21.00000         23.000000               66.0
# 4             25.00000         36.000000               85.0
#
#                                             features
# 0  [41.0, 90.0, 39.79999923706055, 0.451000005006...
# 1  [25.0, 62.0, 34.0, 0.39100000262260437, 76.0, ...
# 2  [27.0, 82.0, 34.20000076293945, 1.292000055313...
# 3  [30.0, 66.0, 24.399999618530273, 0.34200000762...
# 4  [24.0, 85.0, 37.400001525878906, 0.24699999392...

# %%
initial_types = buildInitialTypesSimple(diabetesDF_imputed.drop('label','id','bloodpressure', 'bmi', 'seruminsulin', 'plasmaglucose', 'tricepthickness'))
print(initial_types)
onnx_model = convert_sparkml(assembler, 'Pyspark Vector Assembler model', initial_types, spark_session = spark)
#print(onnx_model.SerializeToString())
# Out:
# The maximum opset needed by this model is only 4.
# [('age', FloatTensorType(shape=[1, 1])), ('diabetespedegree', FloatTensorType(shape=[1, 1])), ('timespregnant', FloatTensorType(shape=[1, 1])), ('out_bmi', FloatTensorType(shape=[1, 1])), ('out_plasmaglucose', FloatTensorType(shape=[1, 1])), ('out_tricepthickness', FloatTensorType(shape=[1, 1])), ('out_seruminsulin', FloatTensorType(shape=[1, 1])), ('out_bloodpressure', FloatTensorType(shape=[1, 1]))]

# %%
with open(os.path.join("/home/jovyan/work/models/", "vector_assembler_model.onnx"), "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
splits = dDF.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1]

print ("Train Dataframe Row Count: ")
print (train.count())
print ("Test Datafram Row Count: ")
print (test.count())
# Out:
# Train Dataframe Row Count:
# 527
# Test Datafram Row Count:
# 241

# %%
rf = RandomForestClassifier(labelCol="label", featuresCol="features", numTrees=10)
rf_model = rf.fit(train)

rf_predictions = rf_model.transform(test)
showDF(rf_predictions)
# Out:
#    id  age  bloodpressure        bmi  diabetespedegree  label  plasmaglucose  \
# 0   5   33           40.0  43.099998             2.288      1          137.0
# 1  28   22           66.0  23.200001             0.487      0           97.0
# 2  30   38           92.0  34.099998             0.337      0          117.0
# 3  42   37           84.0  40.200001             0.696      0          133.0
# 4  52   26           50.0  24.200001             0.526      0          101.0
#
#    seruminsulin  timespregnant  tricepthickness    out_bmi  out_plasmaglucose  \
# 0         168.0              0             35.0  43.099998              137.0
# 1         140.0              1             15.0  23.200001               97.0
# 2           NaN              5              NaN  34.099998              117.0
# 3           NaN              7              NaN  40.200001              133.0
# 4          36.0              1             15.0  24.200001              101.0
#
#    out_tricepthickness  out_seruminsulin  out_bloodpressure  \
# 0             35.00000        168.000000               40.0
# 1             15.00000        140.000000               66.0
# 2             29.15342        155.548223               92.0
# 3             29.15342        155.548223               84.0
# 4             15.00000         36.000000               50.0
#
#                                             features  \
# 0  [33.0, 40.0, 43.099998474121094, 2.28800010681...
# 1  [22.0, 66.0, 23.200000762939453, 0.48699998855...
# 2  [38.0, 92.0, 34.099998474121094, 0.33700001239...
# 3  [37.0, 84.0, 40.20000076293945, 0.695999979972...
# 4  [26.0, 50.0, 24.200000762939453, 0.52600002288...
#
#                               rawPrediction  \
# 0   [2.5457817436052976, 7.454218256394702]
# 1  [9.674142262222148, 0.32585773777785104]
# 2   [5.9262314463222365, 4.073768553677764]
# 3    [3.029922137428934, 6.970077862571066]
# 4   [9.338394907724794, 0.6616050922752055]
#
#                                  probability  prediction
# 0  [0.25457817436052976, 0.7454218256394702]         1.0
# 1   [0.967414226222215, 0.03258577377778511]         0.0
# 2  [0.5926231446322237, 0.40737685536777646]         0.0
# 3   [0.3029922137428934, 0.6970077862571066]         1.0
# 4  [0.9338394907724794, 0.06616050922752055]         0.0

# %%
# compute accuracy on the test set
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                              metricName="accuracy")
rf_score = evaluator.evaluate(rf_predictions)
print("Test set accuracy for Random Forest Classifier = " + str(rf_score))
# Out:
# Test set accuracy for Random Forest Classifier = 0.7717842323651453

# %%
pipeline = Pipeline(stages=[imputer, assembler, rf])

# %%
splits = diabetesDF.randomSplit([0.7, 0.3])
train = splits[0]
test = splits[1]

print ("Train Dataframe Row Count: ")
print (train.count())
print ("Test Datafram Row Count: ")
print (test.count())
# Out:
# Train Dataframe Row Count:
# 563
# Test Datafram Row Count:
# 205

# %%
model = pipeline.fit(train)

# %%
prediction = model.transform(test)
showDF(prediction)
# Out:
#    id  age  bloodpressure        bmi  diabetespedegree  label  plasmaglucose  \
# 0  13   57           80.0  27.100000             1.441      0          139.0
# 1  28   22           66.0  23.200001             0.487      0           97.0
# 2  46   25           66.0  42.000000             1.893      1          180.0
# 3  60   22           64.0  41.500000             0.173      0          105.0
# 4  73   42           90.0  43.400002             0.583      1          126.0
#
#    seruminsulin  timespregnant  tricepthickness    out_bmi  out_plasmaglucose  \
# 0           NaN             10              NaN  27.100000              139.0
# 1         140.0              1             15.0  23.200001               97.0
# 2           NaN              0             39.0  42.000000              180.0
# 3         142.0              0             41.0  41.500000              105.0
# 4           NaN             13              NaN  43.400002              126.0
#
#    out_tricepthickness  out_seruminsulin  out_bloodpressure  \
# 0            29.023499        158.450704               80.0
# 1            15.000000        140.000000               66.0
# 2            39.000000        158.450704               66.0
# 3            41.000000        142.000000               64.0
# 4            29.023499        158.450704               90.0
#
#                                             features  \
# 0  [57.0, 80.0, 27.100000381469727, 1.44099998474...
# 1  [22.0, 66.0, 23.200000762939453, 0.48699998855...
# 2  [25.0, 66.0, 42.0, 1.8930000066757202, 180.0, ...
# 3  [22.0, 64.0, 41.5, 0.17299999296665192, 105.0,...
# 4  [42.0, 90.0, 43.400001525878906, 0.58300000429...
#
#                              rawPrediction  \
# 0    [8.96963459360539, 1.030365406394612]
# 1  [9.430299366199796, 0.5697006338002034]
# 2  [3.2459606383754984, 6.754039361624501]
# 3   [7.652376523677515, 2.347623476322486]
# 4  [6.156169546254334, 3.8438304537456665]
#
#                                  probability  prediction
# 0  [0.8969634593605388, 0.10303654063946117]         0.0
# 1  [0.9430299366199797, 0.05697006338002035]         0.0
# 2  [0.32459606383754985, 0.6754039361624501]         1.0
# 3   [0.7652376523677515, 0.2347623476322486]         0.0
# 4  [0.6156169546254334, 0.38438304537456663]         0.0

# %%
showDF(train)
# Out:
#    id  age  bloodpressure        bmi  diabetespedegree  label  plasmaglucose  \
# 0   1   50           72.0  33.599998             0.627      1          148.0
# 1   2   31           66.0  26.600000             0.351      0           85.0
# 2   5   33           40.0  43.099998             2.288      1          137.0
# 3   8   29            NaN  35.299999             0.134      0          115.0
# 4  10   54           96.0        NaN             0.232      1          125.0
#
#    seruminsulin  timespregnant  tricepthickness
# 0           NaN              6             35.0
# 1           NaN              1             29.0
# 2         168.0              0             35.0
# 3           NaN             10              NaN
# 4           NaN              8              NaN

# %%
initial_types = buildInitialTypesSimple(diabetesDF.drop("label", "id"))
print(initial_types)
onnx_model = convert_sparkml(model, 'Pyspark Pipeline model', initial_types, spark_session = spark)
# Out:
# [('age', FloatTensorType(shape=[1, 1])), ('bloodpressure', FloatTensorType(shape=[1, 1])), ('bmi', FloatTensorType(shape=[1, 1])), ('diabetespedegree', FloatTensorType(shape=[1, 1])), ('plasmaglucose', FloatTensorType(shape=[1, 1])), ('seruminsulin', FloatTensorType(shape=[1, 1])), ('timespregnant', FloatTensorType(shape=[1, 1])), ('tricepthickness', FloatTensorType(shape=[1, 1]))]
# The maximum opset needed by this model is only 4.

# %%
with open(os.path.join("/home/jovyan/work/models/", "pipeline_model.onnx"), "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
session.execute("drop table models")

# %%
query = "CREATE TABLE IF NOT EXISTS models \
                                   (Id int, name text, model blob, description text, PRIMARY KEY (Id))"
session.execute(query)

# %%
query = "INSERT INTO models (Id, name, model, description)"
query = query + " VALUES (%s, %s, %s, %s)"
session.execute(query, (int(0), str("Pipeline Model"), (onnx_model.SerializeToString()), str("Full Pima Indians Diabetes Pipeline Model")))

# %%
print(session.execute("SELECT * FROM models where Id = 0").current_rows[0].model)
# Out:
# b'\x08\x03\x12\x0bOnnxMLTools\x1a\x051.7.0"\x14onnxconverter-common(\x002\x00:\xc1u\np\n\rplasmaglucose\n\rbloodpressure\n\x03bmi\n\x0ftricepthickness\n\x0cseruminsulin\x12\rconcat_tensor\x1a\x06Concat"\x06Concat*\x0b\n\x04axis\x18\x01\xa0\x01\x02:\x00\n\x91\x01\n\rconcat_tensor\x12\x0eimputed_tensor\x1a\x07Imputer"\x07Imputer*2\n\x14imputed_value_floats=up\xf4B=v\x94\x90B=\xb0\xee\x00B= 0\xe8A=as\x1eC\xa0\x01\x06*\x1e\n\x14replaced_value_float\x15\x00\x00\xc0\x7f\xa0\x01\x01:\nai.onnx.ml\n\x97\x01\n\x0eimputed_tensor\x12\x11out_plasmaglucose\x12\x11out_bloodpressure\x12\x07out_bmi\x12\x13out_tricepthickness\x12\x10out_seruminsulin\x1a\x05Split"\x05Split*\x0b\n\x04axis\x18\x01\xa0\x01\x02*\x
#       type: FLOATS
#     }
#     attribute {
#       name: "replaced_value_float"
#       f: nan
#       type: FLOAT
#     }
#     domain: "ai.onnx.ml"
#   }
#   node {
#     input: "imputed_tensor"
#     output: "out_plasmaglucose"
#     output: "out_bloodpressure"
#     output: "out_bmi"
#     output: "out_tricepthickness"
#     output: "out_seruminsulin"
#     name: "Split"
#     op_type: "Split"
#     attribute {
#       name: "axis"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "split"
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 4
#       type: INTS
#     }
#     domain: ""
#   }
#   node {
#     input: "age"
#     input: "out_bloodpressure"
#     input: "out_bmi"
#     input: "diabetespedegree"
#     input: "out_plasmaglucose"
#     input: "out_seruminsulin"
#     input: "timespregnant"
#     input: "out_tricepthickness"
#     output: "features"
#     name: "Concat1"
#     op_type: "Concat"
#     attribute {
#       name: "axis"
#       i: 1
#       type: INT
#     }
#     domain: ""
#   }
#   node {
#     input: "features"
#     output: "prediction"
#     output: "probability"
#     name: "TreeEnsembleClassifier"
#     op_type: "TreeEnsembleClassifier"
#     attribute {
#       name: "class_ids"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "class_nodeids"
#       ints: 5
#       ints: 6
#       ints: 7
#       ints: 9
#       ints: 10
#       ints: 12
#       ints: 15
#       ints: 16
#       ints: 17
#       ints: 21
#       ints: 23
#       ints: 24
#       ints: 27
#       ints: 28
#       ints: 30
#       ints: 31
#       ints: 34
#       ints: 36
#       ints: 37
#       ints: 38
#       ints: 5
#       ints: 6
#       ints: 7
#       ints: 9
#       ints: 10
#       ints: 13
#       ints: 15
#       ints: 16
#       ints: 19
#       ints: 20
#       ints: 22
#       ints: 23
#       ints: 27
#       ints: 29
#       ints: 30
#       ints: 32
#       ints: 33
#       ints: 37
#       ints: 38
#       ints: 39
#       ints: 41
#       ints: 43
#       ints: 44
#       ints: 4
#       ints: 6
#       ints: 7
#       ints: 8
#       ints: 12
#       ints: 13
#       ints: 14
#       ints: 17
#       ints: 18
#       ints: 20
#       ints: 21
#       ints: 25
#       ints: 26
#       ints: 27
#       ints: 30
#       ints: 31
#       ints: 34
#       ints: 35
#       ints: 36
#       ints: 5
#       ints: 6
#       ints: 8
#       ints: 9
#       ints: 12
#       ints: 13
#       ints: 14
#       ints: 17
#       ints: 19
#       ints: 20
#       ints: 21
#       ints: 25
#       ints: 27
#       ints: 28
#       ints: 31
#       ints: 32
#       ints: 33
#       ints: 37
#       ints: 38
#       ints: 40
#       ints: 41
#       ints: 42
#       ints: 4
#       ints: 6
#       ints: 7
#       ints: 9
#       ints: 10
#       ints: 11
#       ints: 13
#       ints: 16
#       ints: 18
#       ints: 19
#       ints: 21
#       ints: 23
#       ints: 24
#       ints: 3
#       ints: 4
#       ints: 8
#       ints: 9
#       ints: 11
#       ints: 12
#       ints: 14
#       ints: 16
#       ints: 17
#       ints: 20
#       ints: 23
#       ints: 24
#       ints: 26
#       ints: 27
#       ints: 31
#       ints: 32
#       ints: 34
#       ints: 35
#       ints: 37
#       ints: 39
#       ints: 40
#       ints: 3
#       ints: 5
#       ints: 7
#       ints: 8
#       ints: 11
#       ints: 13
#       ints: 14
#       ints: 15
#       ints: 20
#       ints: 21
#       ints: 22
#       ints: 25
#       ints: 26
#       ints: 28
#       ints: 29
#       ints: 33
#       ints: 34
#       ints: 36
#       ints: 37
#       ints: 39
#       ints: 41
#       ints: 42
#       ints: 2
#       ints: 5
#       ints: 7
#       ints: 8
#       ints: 10
#       ints: 12
#       ints: 13
#       ints: 17
#       ints: 19
#       ints: 20
#       ints: 22
#       ints: 23
#       ints: 26
#       ints: 28
#       ints: 29
#       ints: 32
#       ints: 33
#       ints: 34
#       ints: 1
#       ints: 5
#       ints: 7
#       ints: 8
#       ints: 11
#       ints: 12
#       ints: 13
#       ints: 16
#       ints: 18
#       ints: 19
#       ints: 21
#       ints: 23
#       ints: 24
#       ints: 3
#       ints: 5
#       ints: 6
#       ints: 10
#       ints: 11
#       ints: 12
#       ints: 15
#       ints: 16
#       ints: 17
#       ints: 20
#       ints: 23
#       ints: 24
#       ints: 26
#       ints: 27
#       ints: 31
#       ints: 32
#       ints: 34
#       ints: 35
#       ints: 37
#       ints: 39
#       ints: 40
#       type: INTS
#     }
#     attribute {
#       name: "class_treeids"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       type: INTS
#     }
#     attribute {
#       name: "class_weights"
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0012048193020746112
#       floats: 0.10000000149011612
#       floats: 0.0058823530562222
#       floats: 0.006779660936444998
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.037704918533563614
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.022727273404598236
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.08030302822589874
#       floats: 0.04285714402794838
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0022346368059515953
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.0027027027681469917
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.02380952425301075
#       floats: 0.10000000149011612
#       floats: 0.07000000029802322
#       floats: 0.023188406601548195
#       floats: 0.0
#       floats: 0.07307692617177963
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.029411764815449715
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.07777778059244156
#       floats: 0.0416666679084301
#       floats: 0.009999999776482582
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.03750000149011612
#       floats: 0.010256410576403141
#       floats: 0.05636363476514816
#       floats: 0.02916666679084301
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.00800000037997961
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0117647061124444
#       floats: 0.06632652878761292
#       floats: 0.09473684430122375
#       floats: 0.0018691589357331395
#       floats: 0.10000000149011612
#       floats: 0.014953271485865116
#       floats: 0.08888889104127884
#       floats: 0.10000000149011612
#       floats: 0.014285714365541935
#       floats: 0.10000000149011612
#       floats: 0.03500000014901161
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.002439024392515421
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.0
#       floats: 0.06086956337094307
#       floats: 0.02869565226137638
#       floats: 0.00909090880304575
#       floats: 0.07619047909975052
#       floats: 0.04545454680919647
#       floats: 0.09200000017881393
#       floats: 0.0
#       floats: 0.008771929889917374
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.02656250074505806
#       floats: 0.0741935446858406
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.008333333767950535
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.010222222656011581
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0022727272007614374
#       floats: 0.024561403319239616
#       floats: 0.05942029133439064
#       floats: 0.0833333358168602
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.07999999821186066
#       floats: 0.0
#       floats: 0.0
#       floats: 0.07333333045244217
#       floats: 0.10000000149011612
#       floats: 0.05000000074505806
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.004268292803317308
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.023333333432674408
#       floats: 0.10000000149011612
#       floats: 0.01702127605676651
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.08888889104127884
#       floats: 0.0
#       floats: 0.008333333767950535
#       floats: 0.07999999821186066
#       floats: 0.04333333298563957
#       floats: 0.10000000149011612
#       floats: 0.08571428805589676
#       floats: 0.02500000037252903
#       floats: 0.08235294371843338
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.00390625
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.006666666828095913
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.0625
#       floats: 0.014285714365541935
#       floats: 0.03500000014901161
#       floats: 0.10000000149011612
#       floats: 0.07450980693101883
#       floats: 0.0
#       floats: 0.06666667014360428
#       floats: 0.0
#       floats: 0.0882352963089943
#       floats: 0.10000000149011612
#       floats: 0.014492753893136978
#       floats: 0.008791209198534489
#       floats: 0.01666666753590107
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.042222220450639725
#       floats: 0.0634615421295166
#       floats: 0.10000000149011612
#       floats: 0.10000000149011612
#       floats: 0.0071428571827709675
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.10000000149011612
#       floats: 0.0
#       floats: 0.0
#       floats: 0.005050505045801401
#       floats: 0.10000000149011612
#       floats: 0.027710843831300735
#       floats: 0.10000000149011612
#       floats: 0.03999999910593033
#       floats: 0.019999999552965164
#       floats: 0.07692307978868484
#       floats: 0.019354838877916336
#       floats: 0.08888889104127884
#       floats: 0.08518518507480621
#       floats: 0.03333333507180214
#       floats: 0.09000000357627869
#       type: FLOATS
#     }
#     attribute {
#       name: "classlabels_int64s"
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "nodes_falsenodeids"
#       ints: 18
#       ints: 11
#       ints: 8
#       ints: 7
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 0
#       ints: 0
#       ints: 13
#       ints: 0
#       ints: 17
#       ints: 16
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 32
#       ints: 25
#       ints: 22
#       ints: 0
#       ints: 24
#       ints: 0
#       ints: 0
#       ints: 29
#       ints: 28
#       ints: 0
#       ints: 0
#       ints: 31
#       ints: 0
#       ints: 0
#       ints: 38
#       ints: 35
#       ints: 0
#       ints: 37
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 24
#       ints: 11
#       ints: 8
#       ints: 7
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 0
#       ints: 0
#       ints: 17
#       ints: 14
#       ints: 0
#       ints: 16
#       ints: 0
#       ints: 0
#       ints: 21
#       ints: 20
#       ints: 0
#       ints: 0
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 34
#       ints: 31
#       ints: 28
#       ints: 0
#       ints: 30
#       ints: 0
#       ints: 0
#       ints: 33
#       ints: 0
#       ints: 0
#       ints: 40
#       ints: 39
#       ints: 38
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 42
#       ints: 0
#       ints: 44
#       ints: 0
#       ints: 0
#       ints: 22
#       ints: 9
#       ints: 8
#       ints: 5
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 15
#       ints: 14
#       ints: 13
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 19
#       ints: 18
#       ints: 0
#       ints: 0
#       ints: 21
#       ints: 0
#       ints: 0
#       ints: 28
#       ints: 27
#       ints: 26
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 32
#       ints: 31
#       ints: 0
#       ints: 0
#       ints: 36
#       ints: 35
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 22
#       ints: 15
#       ints: 10
#       ints: 7
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 9
#       ints: 0
#       ints: 0
#       ints: 14
#       ints: 13
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 21
#       ints: 18
#       ints: 0
#       ints: 20
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 34
#       ints: 29
#       ints: 26
#       ints: 0
#       ints: 28
#       ints: 0
#       ints: 0
#       ints: 33
#       ints: 32
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 42
#       ints: 39
#       ints: 38
#       ints: 0
#       ints: 0
#       ints: 41
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 12
#       ints: 11
#       ints: 8
#       ints: 5
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 14
#       ints: 0
#       ints: 20
#       ints: 17
#       ints: 0
#       ints: 19
#       ints: 0
#       ints: 0
#       ints: 22
#       ints: 0
#       ints: 24
#       ints: 0
#       ints: 0
#       ints: 18
#       ints: 5
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 13
#       ints: 10
#       ints: 9
#       ints: 0
#       ints: 0
#       ints: 12
#       ints: 0
#       ints: 0
#       ints: 15
#       ints: 0
#       ints: 17
#       ints: 0
#       ints: 0
#       ints: 28
#       ints: 21
#       ints: 0
#       ints: 25
#       ints: 24
#       ints: 0
#       ints: 0
#       ints: 27
#       ints: 0
#       ints: 0
#       ints: 36
#       ints: 33
#       ints: 32
#       ints: 0
#       ints: 0
#       ints: 35
#       ints: 0
#       ints: 0
#       ints: 38
#       ints: 0
#       ints: 40
#       ints: 0
#       ints: 0
#       ints: 16
#       ints: 9
#       ints: 4
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 8
#       ints: 0
#       ints: 0
#       ints: 15
#       ints: 12
#       ints: 0
#       ints: 14
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 30
#       ints: 23
#       ints: 22
#       ints: 21
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 27
#       ints: 26
#       ints: 0
#       ints: 0
#       ints: 29
#       ints: 0
#       ints: 0
#       ints: 38
#       ints: 35
#       ints: 34
#       ints: 0
#       ints: 0
#       ints: 37
#       ints: 0
#       ints: 0
#       ints: 40
#       ints: 0
#       ints: 42
#       ints: 0
#       ints: 0
#       ints: 14
#       ints: 3
#       ints: 0
#       ints: 9
#       ints: 6
#       ints: 0
#       ints: 8
#       ints: 0
#       ints: 0
#       ints: 11
#       ints: 0
#       ints: 13
#       ints: 0
#       ints: 0
#       ints: 24
#       ints: 21
#       ints: 18
#       ints: 0
#       ints: 20
#       ints: 0
#       ints: 0
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 30
#       ints: 27
#       ints: 0
#       ints: 29
#       ints: 0
#       ints: 0
#       ints: 34
#       ints: 33
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 14
#       ints: 9
#       ints: 6
#       ints: 0
#       ints: 8
#       ints: 0
#       ints: 0
#       ints: 13
#       ints: 12
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 20
#       ints: 17
#       ints: 0
#       ints: 19
#       ints: 0
#       ints: 0
#       ints: 22
#       ints: 0
#       ints: 24
#       ints: 0
#       ints: 0
#       ints: 18
#       ints: 7
#       ints: 4
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 13
#       ints: 12
#       ints: 11
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 17
#       ints: 16
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 28
#       ints: 21
#       ints: 0
#       ints: 25
#       ints: 24
#       ints: 0
#       ints: 0
#       ints: 27
#       ints: 0
#       ints: 0
#       ints: 36
#       ints: 33
#       ints: 32
#       ints: 0
#       ints: 0
#       ints: 35
#       ints: 0
#       ints: 0
#       ints: 38
#       ints: 0
#       ints: 40
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "nodes_featureids"
#       ints: 4
#       ints: 7
#       ints: 3
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 4
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 4
#       ints: 6
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 3
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 1
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 7
#       ints: 1
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 6
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 3
#       ints: 5
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 2
#       ints: 3
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 3
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 3
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 1
#       ints: 7
#       ints: 7
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 2
#       ints: 4
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 2
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 5
#       ints: 2
#       ints: 0
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 5
#       ints: 0
#       ints: 2
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 3
#       ints: 1
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 3
#       ints: 6
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 5
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 6
#       ints: 0
#       ints: 5
#       ints: 6
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 2
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 4
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 3
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 7
#       ints: 0
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 3
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 2
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 4
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "nodes_hitrates"
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       floats: 1.0
#       type: FLOATS
#     }
#     attribute {
#       name: "nodes_missing_value_tracks_true"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "nodes_modes"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
#       strings: "BRANCH_LEQ"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "LEAF"
#       strings: "BRANCH_LEQ"
# ...
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 9
#       type: INTS
#     }
#     attribute {
#       name: "nodes_truenodeids"
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 4
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 9
#       ints: 0
#       ints: 0
#       ints: 12
#       ints: 0
#       ints: 14
#       ints: 15
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 19
#       ints: 20
#       ints: 21
#       ints: 0
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 26
#       ints: 27
#       ints: 0
#       ints: 0
#       ints: 30
#       ints: 0
#       ints: 0
#       ints: 33
#       ints: 34
#       ints: 0
#       ints: 36
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 4
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 9
#       ints: 0
#       ints: 0
#       ints: 12
#       ints: 13
#       ints: 0
#       ints: 15
#       ints: 0
#       ints: 0
#       ints: 18
#       ints: 19
#       ints: 0
#       ints: 0
#       ints: 22
#       ints: 0
#       ints: 0
#       ints: 25
#       ints: 26
#       ints: 27
#       ints: 0
#       ints: 29
#       ints: 0
#       ints: 0
#       ints: 32
#       ints: 0
#       ints: 0
#       ints: 35
#       ints: 36
#       ints: 37
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 41
#       ints: 0
#       ints: 43
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 4
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 11
#       ints: 12
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 16
#       ints: 17
#       ints: 0
#       ints: 0
#       ints: 20
#       ints: 0
#       ints: 0
#       ints: 23
#       ints: 24
#       ints: 25
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 29
#       ints: 30
#       ints: 0
#       ints: 0
#       ints: 33
#       ints: 34
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 4
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 8
#       ints: 0
#       ints: 0
#       ints: 11
#       ints: 12
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 16
#       ints: 17
#       ints: 0
#       ints: 19
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 23
#       ints: 24
#       ints: 25
#       ints: 0
#       ints: 27
#       ints: 0
#       ints: 0
#       ints: 30
#       ints: 31
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 35
#       ints: 36
#       ints: 37
#       ints: 0
#       ints: 0
#       ints: 40
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 4
#       ints: 0
#       ints: 6
#       ints: 0
#       ints: 0
#       ints: 9
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 13
#       ints: 0
#       ints: 15
#       ints: 16
#       ints: 0
#       ints: 18
#       ints: 0
#       ints: 0
#       ints: 21
#       ints: 0
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 0
#       ints: 0
#       ints: 6
#       ints: 7
#       ints: 8
#       ints: 0
#       ints: 0
#       ints: 11
#       ints: 0
#       ints: 0
#       ints: 14
#       ints: 0
#       ints: 16
#       ints: 0
#       ints: 0
#       ints: 19
#       ints: 20
#       ints: 0
#       ints: 22
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 26
#       ints: 0
#       ints: 0
#       ints: 29
#       ints: 30
#       ints: 31
#       ints: 0
#       ints: 0
#       ints: 34
#       ints: 0
#       ints: 0
#       ints: 37
#       ints: 0
#       ints: 39
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 11
#       ints: 0
#       ints: 13
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 17
#       ints: 18
#       ints: 19
#       ints: 20
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 24
#       ints: 25
#       ints: 0
#       ints: 0
#       ints: 28
#       ints: 0
#       ints: 0
#       ints: 31
#       ints: 32
#       ints: 33
#       ints: 0
#       ints: 0
#       ints: 36
#       ints: 0
#       ints: 0
#       ints: 39
#       ints: 0
#       ints: 41
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 4
#       ints: 5
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 0
#       ints: 12
#       ints: 0
#       ints: 0
#       ints: 15
#       ints: 16
#       ints: 17
#       ints: 0
#       ints: 19
#       ints: 0
#       ints: 0
#       ints: 22
#       ints: 0
#       ints: 0
#       ints: 25
#       ints: 26
#       ints: 0
#       ints: 28
#       ints: 0
#       ints: 0
#       ints: 31
#       ints: 32
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 0
#       ints: 3
#       ints: 4
#       ints: 5
#       ints: 0
#       ints: 7
#       ints: 0
#       ints: 0
#       ints: 10
#       ints: 11
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 15
#       ints: 16
#       ints: 0
#       ints: 18
#       ints: 0
#       ints: 0
#       ints: 21
#       ints: 0
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 3
#       ints: 0
#       ints: 5
#       ints: 0
#       ints: 0
#       ints: 8
#       ints: 9
#       ints: 10
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 14
#       ints: 15
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 19
#       ints: 20
#       ints: 0
#       ints: 22
#       ints: 23
#       ints: 0
#       ints: 0
#       ints: 26
#       ints: 0
#       ints: 0
#       ints: 29
#       ints: 30
#       ints: 31
#       ints: 0
#       ints: 0
#       ints: 34
#       ints: 0
#       ints: 0
#       ints: 37
#       ints: 0
#       ints: 39
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "nodes_values"
#       floats: 133.5
#       floats: 24.5
#       floats: 0.6605000495910645
#       floats: 0.5
#       floats: 22.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 55.5
#       floats: 0.0
#       floats: 0.0
#       floats: 128.5
#       floats: 0.0
#       floats: 94.5
#       floats: 36.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 31.450000762939453
#       floats: 162.5
#       floats: 1.5
#       floats: 0.0
#       floats: 2.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.31450000405311584
#       floats: 0.2685000002384186
#       floats: 0.0
#       floats: 0.0
#       floats: 24.5
#       floats: 0.0
#       floats: 0.0
#       floats: 89.0
#       floats: 79.0
#       floats: 0.0
#       floats: 43.349998474121094
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 129.5
#       floats: 28.5
#       floats: 39.5
#       floats: 51.0
#       floats: 29.511749267578125
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 69.0
#       floats: 0.0
#       floats: 0.0
#       floats: 94.5
#       floats: 10.5
#       floats: 0.0
#       floats: 29.511749267578125
#       floats: 0.0
#       floats: 0.0
#       floats: 33.5
#       floats: 6.5
#       floats: 0.0
#       floats: 0.0
#       floats: 1.5
#       floats: 0.0
#       floats: 0.0
#       floats: 29.75
#       floats: 51.5
#       floats: 1.5
#       floats: 0.0
#       floats: 81.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.14350000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 0.25349998474121094
#       floats: 166.5
#       floats: 85.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 142.5
#       floats: 0.0
#       floats: 0.9639999866485596
#       floats: 0.0
#       floats: 0.0
#       floats: 4.5
#       floats: 27.5
#       floats: 46.150001525878906
#       floats: 0.9639999866485596
#       floats: 0.0
#       floats: 29.100000381469727
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 31.450000762939453
#       floats: 0.28450000286102295
#       floats: 73.14498138427734
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 43.5
#       floats: 30.5
#       floats: 0.0
#       floats: 0.0
#       floats: 88.5
#       floats: 0.0
#       floats: 0.0
#       floats: 128.5
#       floats: 0.7799999713897705
#       floats: 12.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 94.5
#       floats: 30.5
#       floats: 0.0
#       floats: 0.0
#       floats: 180.5
#       floats: 27.349998474121094
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5
#       floats: 83.0
#       floats: 41.5
#       floats: 29.011749267578125
#       floats: 381.0
#       floats: 0.0
#       floats: 0.0
#       floats: 162.5
#       floats: 0.0
#       floats: 0.0
#       floats: 156.5
#       floats: 0.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 101.0
#       floats: 43.349998474121094
#       floats: 0.0
#       floats: 0.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 133.5
#       floats: 26.450000762939453
#       floats: 127.5
#       floats: 0.0
#       floats: 115.5
#       floats: 0.0
#       floats: 0.0
#       floats: 31.450000762939453
#       floats: 66.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 42.5
#       floats: 29.75
#       floats: 146.5
#       floats: 0.0
#       floats: 0.0
#       floats: 67.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 27.5
#       floats: 87.0
#       floats: 381.0
#       floats: 46.150001525878906
#       floats: 0.0
#       floats: 0.25949999690055847
#       floats: 0.0
#       floats: 0.0
#       floats: 36.349998474121094
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 117.5
#       floats: 0.0
#       floats: 56.5
#       floats: 381.0
#       floats: 0.0
#       floats: 24.5
#       floats: 0.0
#       floats: 0.0
#       floats: 81.0
#       floats: 0.0
#       floats: 19.5
#       floats: 0.0
#       floats: 0.0
#       floats: 146.5
#       floats: 28.5
#       floats: 46.150001525878906
#       floats: 0.0
#       floats: 0.0
#       floats: 158.72535705566406
#       floats: 27.349998474121094
#       floats: 29.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.2979999780654907
#       floats: 0.0
#       floats: 0.0
#       floats: 56.5
#       floats: 0.0
#       floats: 5.5
#       floats: 0.0
#       floats: 0.0
#       floats: 30.150001525878906
#       floats: 158.22535705566406
#       floats: 0.0
#       floats: 27.75
#       floats: 0.14350000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 29.511749267578125
#       floats: 0.0
#       floats: 0.0
#       floats: 0.9639999866485596
#       floats: 74.5
#       floats: 128.5
#       floats: 0.0
#       floats: 0.0
#       floats: 41.5
#       floats: 0.0
#       floats: 0.0
#       floats: 29.011749267578125
#       floats: 0.0
#       floats: 22.5
#       floats: 0.0
#       floats: 0.0
#       floats: 117.5
#       floats: 0.6605000495910645
#       floats: 3.5
#       floats: 0.0
#       floats: 26.450000762939453
#       floats: 0.0
#       floats: 24.5
#       floats: 0.0
#       floats: 0.0
#       floats: 41.5
#       floats: 55.5
#       floats: 0.0
#       floats: 8.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 27.75
#       floats: 25.5
#       floats: 54.5
#       floats: 51.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 23.5
#       floats: 10.5
#       floats: 0.0
#       floats: 0.0
#       floats: 142.5
#       floats: 0.0
#       floats: 0.0
#       floats: 156.5
#       floats: 39.5
#       floats: 46.150001525878906
#       floats: 0.0
#       floats: 0.0
#       floats: 38.04999923706055
#       floats: 0.0
#       floats: 0.0
#       floats: 43.349998474121094
#       floats: 0.0
#       floats: 25.5
#       floats: 0.0
#       floats: 0.0
#       floats: 27.75
#       floats: 6.5
#       floats: 0.0
#       floats: 158.22535705566406
#       floats: 7.5
#       floats: 0.0
#       floats: 138.5
#       floats: 0.0
#       floats: 0.0
#       floats: 32.5
#       floats: 0.0
#       floats: 27.349998474121094
#       floats: 0.0
#       floats: 0.0
#       floats: 129.5
#       floats: 128.5
#       floats: 27.5
#       floats: 0.0
#       floats: 2.5
#       floats: 0.0
#       floats: 0.0
#       floats: 48.5
#       floats: 0.0
#       floats: 0.0
#       floats: 41.400001525878906
#       floats: 38.04999923706055
#       floats: 0.0
#       floats: 162.5
#       floats: 0.0
#       floats: 0.0
#       floats: 6.5
#       floats: 0.19550000131130219
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 29.75
#       floats: 0.0
#       floats: 26.5
#       floats: 150.5
#       floats: 129.5
#       floats: 0.0
#       floats: 3.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.28450000286102295
#       floats: 381.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 10.5
#       floats: 18.5
#       floats: 0.0
#       floats: 0.20800000429153442
#       floats: 0.0
#       floats: 0.0
#       floats: 38.5
#       floats: 0.0
#       floats: 26.5
#       floats: 0.0
#       floats: 0.0
#       floats: 21.5
#       floats: 27.5
#       floats: 162.5
#       floats: 0.0
#       floats: 0.5
#       floats: 0.0
#       floats: 0.0
#       floats: 3.5
#       floats: 0.4645000100135803
#       floats: 69.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 30.5
#       floats: 63.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 129.5
#       floats: 25.5
#       floats: 0.0
#       floats: 162.5
#       floats: 51.0
#       floats: 0.0
#       floats: 0.0
#       floats: 26.5
#       floats: 0.0
#       floats: 0.0
#       floats: 33.75
#       floats: 73.14498138427734
#       floats: 22.5
#       floats: 0.0
#       floats: 0.0
#       floats: 87.0
#       floats: 0.0
#       floats: 0.0
#       floats: 277.5
#       floats: 0.0
#       floats: 156.5
#       floats: 0.0
#       floats: 0.0
#       type: FLOATS
#     }
#     attribute {
#       name: "post_transform"
#       s: "NONE"
#       type: STRING
#     }
#     domain: "ai.onnx.ml"
#   }
#   name: "Pyspark Pipeline model"
#   input {
#     name: "age"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bloodpressure"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "bmi"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "diabetespedegree"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "plasmaglucose"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "seruminsulin"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "timespregnant"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "tricepthickness"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "prediction"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "probability"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 2
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: "ai.onnx.ml"
#   version: 1
# }
# opset_import {
#   domain: ""
#   version: 4
# }

# %%
onnxsession = onnxruntime.InferenceSession("/home/jovyan/work/models/pipeline_model.onnx", None)
output = onnxsession.get_outputs()[0]
inputs = onnxsession.get_inputs()
print(inputs[7])
print("\n")
#test_row = test.drop("label", "id").collect()[1]
#print(test_row)
#test_row_DF = spark.createDataFrame(spark.sparkContext.parallelize(test_row), test.drop("label", "id").schema)
print(test.drop("label", "id").schema)
input_data = {}
input_data['age'] = np.float32(test.select("age").toPandas().values[1].reshape(1,1))
input_data['bloodpressure'] = np.float32(test.select("bloodpressure").toPandas().values[1].reshape(1,1))
print(input_data["bloodpressure"].dtype)
input_data['bmi'] = np.float32(test.select("bmi").toPandas().values[1].reshape(1,1))
input_data['diabetespedegree'] = np.float32(test.select("diabetespedegree").toPandas().values[1].reshape(1,1))
input_data['plasmaglucose'] = np.float32(test.select("plasmaglucose").toPandas().values[1].reshape(1,1))
input_data['seruminsulin'] = np.float32(test.select("seruminsulin").toPandas().values[1].reshape(1,1))
input_data['timespregnant'] = np.float32(test.select("timespregnant").toPandas().values[1].reshape(1,1))
input_data['tricepthickness'] = np.float32(test.select("tricepthickness").toPandas().values[1].reshape(1,1))
print(input_data)
#input_data= buildInputDictSimple(test_row_DF)
results = onnxsession.run(None, input_data)
# Out:
# NodeArg(name='tricepthickness', type='tensor(float)', shape=[1, 1])
#
#
# StructType(List(StructField(age,IntegerType,true),StructField(bloodpressure,DoubleType,true),StructField(bmi,DoubleType,true),StructField(diabetespedegree,FloatType,true),StructField(plasmaglucose,DoubleType,true),StructField(seruminsulin,DoubleType,true),StructField(timespregnant,IntegerType,true),StructField(tricepthickness,DoubleType,true)))
# float32
# {'age': array([[22.]], dtype=float32), 'bloodpressure': array([[66.]], dtype=float32), 'bmi': array([[23.2]], dtype=float32), 'diabetespedegree': array([[0.487]], dtype=float32), 'plasmaglucose': array([[97.]], dtype=float32), 'seruminsulin': array([[140.]], dtype=float32), 'timespregnant': array([[1.]], dtype=float32), 'tricepthickness': array([[15.]], dtype=float32)}
# ---------------------------------------------------------------------------
# Fail                                      Traceback (most recent call last)
# <ipython-input-199-f294576eec05> in <module>
#      20 print(input_data)
#      21 #input_data= buildInputDictSimple(test_row_DF)
# ---> 22 results = onnxsession.run(None, input_data)
#
# /opt/conda/lib/python3.7/site-packages/onnxruntime/capi/session.py in run(self, output_names, input_feed, run_options)
#     108             output_names = [output.name for output in self._outputs_meta]
#     109         try:
# --> 110             return self._sess.run(output_names, input_feed, run_options)
#     111         except C.EPFail as err:
#     112             if self._enable_fallback:
#
# Fail: [ONNXRuntimeError] : 1 : FAIL : Non-zero status code returned while running Split node. Name:'Split' Status Message: Cannot split using values in 'split' attribute. Axis=1 Input shape={1,5} NumOutputs=5 Num entries in 'split' (must equal number of outputs) was 4 Sum of sizes in 'split' (must equal size of selected axis) was 10
